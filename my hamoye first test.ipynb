# %%
import pandas as pd

# %% [raw]
# url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv
# test_data = pd.read_csv(url)
# test_data.head(10)

# %%
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
test_data = pd.read_csv(url)
test_data.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# ...

# %%
#Q1
A = [1,2,3,4,5,6]
B = [13, 21, 34]
A.extend(B)
A
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
id = np.eye(3)
id
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#2
import numpy as np
identity_data = np.identity(3)
identity_data
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#Q4
test_data.groupby('fuel_cost_per_unit_burned')['fuel_cost_per_unit_burned'].count()
# Out:
# fuel_cost_per_unit_burned
# -276.080       1
# -174.670       1
# -123.310       1
# -119.040       1
# -85.760        1
#               ..
#  65137.588     1
#  69785.215     1
#  80459.000     1
#  83538.000     1
#  139358.000    1
# Name: fuel_cost_per_unit_burned, Length: 19416, dtype: int64

# %%
test_data.groupby('fuel_type_code_pudl')['fuel_type_code_pudl'].count()
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: fuel_type_code_pudl, dtype: int64

# %%
#Q4
test_data['fuel_cost_per_unit_burned'].min()
# Out:
# -276.08

# %%
#Q4 the describe method will be used
test_data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
#Q5
print(test_data.kurtosis())
test_data.skew()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
#Q6 isnull() function will be used to get the amount of missing values
test_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
print(test_data.count())
# % of the missing value is calculated as below
missing_percent = 180/29523 * 100
print(missing_percent)
# Out:
# record_id                       29523
# utility_id_ferc1                29523
# report_year                     29523
# plant_name_ferc1                29523
# fuel_type_code_pudl             29523
# fuel_unit                       29343
# fuel_qty_burned                 29523
# fuel_mmbtu_per_unit             29523
# fuel_cost_per_unit_burned       29523
# fuel_cost_per_unit_delivered    29523
# fuel_cost_per_mmbtu             29523
# dtype: int64
# 0.609694136774718

# %%
Q8 the corr() method is used
cor = test_data.corr()
cor
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
#9
test_data.head(20)
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 0    f1_fuel_1994_12_1_0_7                 1         1994
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
# 11   f1_fuel_1994_12_4_0_4                 4         1994
# 12   f1_fuel_1994_12_4_0_5                 4         1994
# 13   f1_fuel_1994_12_6_0_1                 6         1994
# 14   f1_fuel_1994_12_6_0_2                 6         1994
# ...

# %% [markdown]
# ###

# %%
#Q10
test_data.groupby('fuel_cost_per_unit_delivered')['fuel_cost_per_unit_delivered'].count()
# Out:
# fuel_cost_per_unit_delivered
# -874.937        1
# -488.054        1
# -313.410        1
# -174.670        3
# -170.187        1
#                ..
#  1942979.000    1
#  2114508.000    1
#  2255688.000    1
#  7793482.000    1
#  7964521.000    1
# Name: fuel_cost_per_unit_delivered, Length: 16675, dtype: int64

# %%
import seaborn as sns
sns.barplot(test_data['fuel_cost_per_unit_delivered'], test_data['report_year'])
